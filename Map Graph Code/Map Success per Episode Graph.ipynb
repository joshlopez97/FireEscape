# %%
from __future__ import division
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import scipy as sp
from scipy.optimize import curve_fit
np.random.seed(0)
# %matplotlib inline

def exponenial_func(x, a, b, c):
    return a*np.exp(-b*x)+c

y = np.loadtxt('DeepQLearning2Stats/DeepQLearning2_map1_success.dat') #(X,Y)
x = []

for i in range(len(y)):
    x.append(i)
    
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.plot(x, y, 'b', linewidth=2)

plt.axis([-50, 2510, -50, 2200])
plt.xlabel('Number of Episodes')
plt.ylabel('Number of Success')
plt.title('Map1 Number of Success Per Episode')
plt.plot()
# Out:
# [   0.    0.    0. ... 2168. 2169. 2170.]
# []

# %%
y = np.loadtxt('DeepQLearning2Stats/DeepQLearning2_map2_success.dat') #(X,Y)
x.clear()

for i in range(len(y)):
    x.append(i)
    
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.plot(x, y, 'b', linewidth=2)

plt.axis([-50, 2510, -50, 2200])
plt.xlabel('Number of Episodes')
plt.ylabel('Number of Success')
plt.title('Map2 Number of Success Per Episode')
plt.plot()
# Out:
# [   0.    0.    0. ... 2127. 2128. 2129.]
# []

# %%
y = np.loadtxt('DeepQLearning2Stats/DeepQLearning2_map3_success.dat') #(X,Y)
x.clear()

for i in range(len(y)):
    x.append(i)
    
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.plot(x, y, 'b', linewidth=2)

plt.axis([-50, 2510, -50, 2200])
plt.xlabel('Number of Episodes')
plt.ylabel('Number of Success')
plt.title('Map3 Number of Success Per Episode')
plt.plot()
# Out:
# [   0.    0.    0. ... 2123. 2124. 2125.]
# []
