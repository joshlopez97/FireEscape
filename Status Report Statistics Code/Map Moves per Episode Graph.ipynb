# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import scipy as sp
from scipy.optimize import curve_fit
np.random.seed(0)
# %matplotlib inline

def exponenial_func(x, a, b, c):
    return a*np.exp(-b*x)+c

y = np.loadtxt('DeepQLearning2Stats/DeepQLearning2_map1_moves.dat') #(X,Y)
x = []

for i in range(len(y)):
    x.append(i)
    
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.bar(x, y)

plt.axis([-50, 2510, -0.5, 30])
plt.xlabel('Number of Episodes')
plt.ylabel('Number of Moves')
plt.title('Map1 Moves per Episode')
plt.plot()
# Out:
# []

# %%
y = np.loadtxt('DeepQLearning2Stats/DeepQLearning2_map2_moves.dat') #(X,Y)
x = []

for i in range(len(y)):
    x.append(i)
    
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.bar(x, y)

plt.axis([-50, 2510, -0.5, 30])
plt.xlabel('Number of Episodes')
plt.ylabel('Number of Moves')
plt.title('Map2 Moves per Episode')
plt.plot()
# Out:
# []

# %%
y = np.loadtxt('DeepQLearning2Stats/DeepQLearning2_map3_moves.dat') #(X,Y)
x = []

for i in range(len(y)):
    x.append(i)
    
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.bar(x, y)

plt.axis([-50, 2510, -0.5, 30])
plt.xlabel('Number of Episodes')
plt.ylabel('Number of Moves')
plt.title('Map3 Moves per Episode')
plt.plot()
# Out:
# []

# %%
y = np.loadtxt('DeepQLearning2Stats/DeepQLearning2_map5_moves.dat') #(X,Y)
x = []

for i in range(len(y)):
    x.append(i)
    
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.bar(x, y)

plt.axis([-50, 4010, -0.5, 30])
plt.xlabel('Number of Episodes')
plt.ylabel('Number of Moves')
plt.title('Map4 Moves per Episode')
plt.plot()
# Out:
# []
